# %%
# Imports para login

# %%
import mechanize

# %%
from bs4 import BeautifulSoup

# %%
import urllib # pip install requests

# %%
import http.cookiejar # pip install cookiejar

# %%
cj = http.cookiejar.CookieJar()

# %%
br = mechanize.Browser()

# %%
br.set_handle_robots(False) ## ignora robots.txt

# %%
br.set_cookiejar(cj)

# %%
br.open("http://10.155.2.18:8080/ingrid_bdgd/") # vai retornar um response_seek_wrapper mas é normal
# Out:
# <response_seek_wrapper at 0x1c239de5b10 whose wrapped object = <closeable_response at 0x1c239e37670 whose fp = <_io.BufferedReader>>>

# %%
br.select_form(nr=0)

# %%
br.form['id_usuario'] = 'coord'
br.form['senha'] = 'indra'
br.submit()  # vai retornar um response_seek_wrapper mas é normal
# Out:
# <response_seek_wrapper at 0x1c239e37190 whose wrapped object = <closeable_response at 0x1c2386f09a0 whose fp = <_io.BufferedReader name=488>>>

# %%
print(br.response().read())
# Out:
# b'\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n<meta charset="ISO-8859-1">\r\n<title>InGRID BDGD</title>\r\n\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n\r\n<link rel="shortcut icon" href="img/indra.ico" type="image/vnd.microsoft.icon" id="favicon">\r\n<!--  Estilos del formulario para testear el API del componente IGEA -->\r\n<link href="css/igea/componentes.css" rel="stylesheet" type="text/css"/>\r\n<link href="css/igea/igea.min.css" rel="stylesheet" type="text/css"/>\r\n<link href="css/igea/igea_indra.css" rel="stylesheet" type="text/css"/>\r\n\r\n<link href="css/bootstrap/dist/css/bootstrap.css" rel="stylesheet" type="text/css" />\r\n<!--<link href="css/bootstrap/dist/css/bootstrap-theme.css" rel="stylesheet" type="text/css" />-->\r\n\r\n<link href="css/toastr/toastr.css" rel="stylesheet" type="text/css" />\r\n\r\n<link href="css/bootstrap/dist/css/datepicker.css" rel="stylesheet" type="text/css" />\r\n\r\n<!-- Liberias JQUERY  -->\r\n<script type="text/javascript" src="js/jquery/jquery-1.11.0.min.js"></script>\r\n<script src="js/jquery/jquery-ui.js" type="text/javascript"></script>\r\n<script src="js/toastr/toastr.min.js" type="text/javascript"></script>\r\n\r\n\r\n<script src="css/bootstrap/dist/js/bootstrap.js" type="text/javascript"></script>\r\n\r\n<!-- Dynatree\r\n<script type="text/javascript" src="js/external/dynatree/jquery-ui.custom.js"></script>-->\r\n<script type="text/javascript" src="js/external/dynatree/jquery.dynatree.js"></script>\r\n\r\n<!-- Librerias constantes y configuraci\xc3\xb3n de IGEAweb -->\r\n<script type="text/javascript" src="js/igea/Config.js"></script>\r\n<script type="text/javascript" src="js/igea/Constantes.js"></script>\r\n\r\n<!-- A\xc3\xb1adimos las librerias de IGEAweb -->\r\n<script type="text/javascript" src="js/igea/igea.js"></script>\r\n<script type="text/javascript" src="js/igea/igeaTools.js"></script>\r\n<script type="text/javascript" src="js/igea/Validacao.js" charset="utf-8"></script>\r\n\r\n<!-- jTable Metro styles. -->\r\n<link href="css/jtable/jtable.css" rel="stylesheet" type="text/css" />\r\n<link href="css/jquery/jquery-ui.css" rel="stylesheet" type="text/css" />\r\n\r\n<!-- Multi Select styles. -->\r\n<link href="css/jquery/bootstrap-multiselect.css" rel="stylesheet" type="text/css" />\r\n\r\n<!-- jTable script file. -->\r\n<script src="js/jquery/jquery.jtable.js" type="text/javascript"></script>\r\n<script src="js/jquery/jquery.jtable.pt-BR.js" type="text/javascript"></script>\r\n<script src="js/alasql/alasql.js" type="text/javascript"></script>\r\n<script src="js/alasql/xls.core.min.js" type="text/javascript"></script>\r\n<script src="js/alasql/xlsx.core.min.js" type="text/javascript"></script>\r\n<script src="js/external/alert.js" type="text/javascript"></script>\r\n<script src="js/external/bootstrap-multiselect.js" type="text/javascript"></script>\r\n<style type="text/css">\r\n\t.datepicker {\r\n    \tz-index: 1151 !important;\r\n\t}\r\n\r\n    .bootstrap-timepicker-widget.dropdown-menu.open {\r\n    \tz-index: 1151 !important;\r\n\t}\r\n</style>\r\n<script type="text/javascript">\r\n\r\n\tvar entidadesJson = [];\r\n\r\n\t/* Instanciamos el heraramienta de filtros */\r\n\tvar __filtros;\r\n\r\n\t//Instanciamos el heraramienta de localizacion de entidades\r\n\tvar __localizar;\r\n\r\n\t/* Instanciamos el objeto Mapa */\r\n\tvar igeaweb;\r\n\tvar s_capas = "";\r\n\tvar arr_capas = {};\r\n\r\n\t$(document).ready(function() {\r\n\t\tigeaweb = new Igeaweb({contenedorMapaId: \'map-container\',\r\n\t\t\t\t\t\t\t\t\tcoordLon: Config.ZOOM_ORIG_LON,\r\n\t\t\t\t\t\t\t\t\tcoordLat: Config.ZOOM_ORIG_LAT,\r\n\t\t\t\t\t\t\t\t\tzoomOrig: 8,\r\n\t\t\t\t\t\t\t\t\tserverUrl: Config.SERVER_ROOT,\r\n\t\t\t\t\t\t\t\t\tarbolCapas: true,\r\n\t\t\t\t\t\t\t\t\tosm: true,\r\n\r\n\t\t\t\t\t\t\t\t\tnotas: true,\r\n\t\t\t\t\t\t\t\t\tzooms: true,\r\n\r\n\t\t\t\t\t\t\t\t\tperfil: 69,\r\n\t\t\t\t\t\t\t ...

# %%
soup = BeautifulSoup(br.response().read(), 'lxml') # pip install lxml

# %%
spans = soup.find_all('a', {'href': 'Monitor.jsp'})
spans[0]
# Out:
# <a data-target="#agendar-extrator" data-toggle="modal" href="Monitor.jsp"><f class="glyphicon glyphicon-time"></f><label>Agendar Extração</label></a>

# %%
br.follow_link(text_regex=r"cheese\s*shop", nr=1)
